jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1774.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3298.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1040.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_442.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2527.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2075.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2255.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3159.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1243.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1205.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1241.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2928.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3395.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_217.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1708.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1353.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_742.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1799.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1513.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1863.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_317.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1693.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2161.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_729.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1848.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2613.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1278.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1538.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2802.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1369.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_354.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_825.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3550.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1429.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2707.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2146.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_907.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2434.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3051.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1711.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_630.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1893.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_214.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_775.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1171.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_234.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3530.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_673.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_227.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2027.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1056.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3335.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3219.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1564.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2541.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2529.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_345.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_12.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3587.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2663.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_929.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1867.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3518.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2828.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3600.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2000.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1435.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1422.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2654.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2732.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_923.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2137.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2540.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2423.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1078.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3265.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_807.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1207.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_879.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2530.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2510.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2999.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1425.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2750.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2552.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_934.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_320.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3324.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_542.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2958.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1109.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1470.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_52.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2389.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2393.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1682.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_427.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1200.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3273.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1912.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2363.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_33.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1022.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1871.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1561.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2645.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2467.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3364.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3279.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2659.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_468.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2592.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_247.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_689.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_601.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2697.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2635.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1933.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3211.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1695.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2830.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_951.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_213.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3154.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2946.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1881.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1103.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_921.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_730.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3596.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1801.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1737.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_661.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_138.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2247.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2506.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_72.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2728.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_389.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2785.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1791.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1057.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3401.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1354.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_332.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1472.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1813.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1329.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2759.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3433.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3677.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_47.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_3255.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2993.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_830.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1680.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_1684.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_182.jpg
# /kaggle/input/face-mask-dataset/data/with_mask/with_mask_2507.jpg

# %% [markdown]
# ## 1. Load necessary libraries

# %%
import matplotlib.pyplot as plt
from PIL import Image
from keras.models import Sequential
import keras, shutil
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AveragePooling2D, Input, BatchNormalization, Activation, Add
from keras.initializers import glorot_uniform
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## 2. Load Data

# %%
path = '/kaggle/input/face-mask-dataset/data'
# print directories
print(os.listdir(path))

# print number of samples in each class
print("with_mask samples: ", len(os.listdir(os.path.join(path, 'with_mask'))))
print("without_mask samples: ", len(os.listdir(os.path.join(path, "without_mask"))))
# Out:
# ['without_mask', 'with_mask']
# with_mask samples:  3725
# without_mask samples:  3828

# %%
os.mkdir('/kaggle/temp')
os.mkdir('/kaggle/temp/with_mask')
os.mkdir('/kaggle/temp/without_mask')

for filename1, filename2 in zip(os.listdir(path + '/with_mask'), os.listdir(path + '/without_mask')):
    shutil.copy(os.path.join(path, 'with_mask/' + filename1), '/kaggle/temp/with_mask')
    shutil.copy(os.path.join(path, 'without_mask/' + filename2), '/kaggle/temp/without_mask')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-71-2bd5f56998d1> in <module>
# ----> 1 os.mkdir('/kaggle/temp')
#       2 os.mkdir('/kaggle/temp/with_mask')
#       3 os.mkdir('/kaggle/temp/without_mask')
#       4
#       5 for filename1, filename2 in zip(os.listdir(path + '/with_mask'), os.listdir(path + '/without_mask')):
#
# FileExistsError: [Errno 17] File exists: '/kaggle/temp'

# %% [markdown]
# as you can see that **with_mask** class contains 3725 samples and **without_mask** contains 3828 samples.

# %% [markdown]
# Now  let's create training and validation set. To create training and validation set, first i will create the temp directory and inside this directory i will create the "train" and "val" directory. Both directories ('train' and 'val') will also have the sub directories 'with_mask' and 'without_mask'.
#
# After that I will move 2800 images from each class to train directory and rest of images will be used as the validation set which i will move to the val directory.
#
# It means that out of 7553 samples (images), 5600 samples will be used for the training set and 1952 (about 26%) will be used as the validation set.

# %%
# create necessary directories for training and validation set
temp_path = '/kaggle/temp/'
#os.mkdir(temp_path)

os.mkdir(os.path.join(temp_path, 'train'))
os.mkdir(os.path.join(temp_path, 'train/with_mask'))
os.mkdir(os.path.join(temp_path, 'train/without_mask'))

os.mkdir(os.path.join(temp_path, 'val'))
os.mkdir(os.path.join(temp_path, 'val/with_mask'))
os.mkdir(os.path.join(temp_path, 'val/without_mask'))

# print directories
print(os.listdir(temp_path))
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-72-5969bbcb3df7> in <module>
#       3 #os.mkdir(temp_path)
#       4
# ----> 5 os.mkdir(os.path.join(temp_path, 'train'))
#       6 os.mkdir(os.path.join(temp_path, 'train/with_mask'))
#       7 os.mkdir(os.path.join(temp_path, 'train/without_mask'))
#
# FileExistsError: [Errno 17] File exists: '/kaggle/temp/train'

# %%
# Move the data from '/kaggle/input/face-mask-detection/data' to 'train' and 'val' directories

path = '/kaggle/temp/'

# move to 'train' directory
for filename in os.listdir(os.path.join(path, 'with_mask'))[0:2800]:
    src_path = os.path.join(path, 'with_mask/' + filename)
    dst_path = os.path.join(temp_path, 'train/with_mask/')
    shutil.move(src_path, dst_path)

for filename in os.listdir(os.path.join(path, 'without_mask'))[0:2800]:
    src_path = os.path.join(path , 'without_mask/' + filename)
    dst_path = os.path.join(temp_path, 'train/without_mask/')
    shutil.move(src_path, dst_path)
    
# move rest of the files to the 'val' directory
for filename in os.listdir(os.path.join(path, 'with_mask')):
    src_path = os.path.join(path, 'with_mask/' + filename)
    dst_path = os.path.join(temp_path, 'val/with_mask/')
    shutil.move(src_path, dst_path)
    
for filename in os.listdir(os.path.join(path, 'without_mask')):
    src_path = os.path.join(path, 'without_mask/' + filename)
    dst_path = os.path.join(temp_path, 'val/without_mask/')
    shutil.move(src_path, dst_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-73-e94eabf17f62> in <module>
#       4
#       5 # move to 'train' directory
# ----> 6 for filename in os.listdir(os.path.join(path, 'with_mask'))[0:2800]:
#       7     src_path = os.path.join(path, 'with_mask/' + filename)
#       8     dst_path = os.path.join(temp_path, 'train/with_mask/')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/temp/with_mask'

# %%
# remove 'with_mask' and 'without_mask' directory from '/kaggle/temp/'
os.rmdir(path + 'with_mask')
os.rmdir(path + 'without_mask')

print(os.listdir(path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-74-a33a9343bfaa> in <module>
#       1 # remove 'with_mask' and 'without_mask' directory from '/kaggle/temp/'
# ----> 2 os.rmdir(path + 'with_mask')
#       3 os.rmdir(path + 'without_mask')
#       4
#       5 print(os.listdir(path))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/temp/with_mask'

# %%
# print number of samples in training and validation set
print("\n ---------------  Training samples  ------------------ \n")
print("with_mask samples: ", len(os.listdir(os.path.join(path, 'train/with_mask'))))
print("without_mask samples: ", len(os.listdir(os.path.join(path, 'train/without_mask'))))

print("\n ---------------  Validation samples  --------------------\n")
print("with_mask samples: ", len(os.listdir(os.path.join(path, 'val/with_mask'))))
print("without_mask samples: ", len(os.listdir(os.path.join(path, 'val/without_mask'))))
# Out:
#  ---------------  Training samples  ------------------
#
# with_mask samples:  2800
# without_mask samples:  2800
#
#  ---------------  Validation samples  --------------------
#
# with_mask samples:  925
# without_mask samples:  925

# %%
# create Image Data Generator
datagen = ImageDataGenerator(rescale = 1.0/255, horizontal_flip = True, 
                            rotation_range = 20, 
                            width_shift_range =  0.2,
                            height_shift_range = 0.2)

train_batch_size = 32
train_dir = '/kaggle/temp/train/'

# create train generator
train_gen = datagen.flow_from_directory(train_dir,
                                       target_size = (224, 224),
                                       batch_size = train_batch_size,
                                       class_mode = 'categorical')

val_batch_size = 32
val_dir = '/kaggle/temp/val/'

# create val generator
val_gen = datagen.flow_from_directory(val_dir,
                                     target_size = (224, 224),
                                     batch_size = val_batch_size,
                                     class_mode = 'categorical')
# Out:
# Found 5600 images belonging to 2 classes.
# Found 1850 images belonging to 2 classes.

# %%
# print label encoding
print(train_gen.class_indices)
# Out:
# {'with_mask': 0, 'without_mask': 1}

# %%
# get number of samples in training set and val set
train_num_samples = 0

for _, _, filenames in os.walk('/kaggle/temp/train/'):
    train_num_samples += len(filenames)
    
val_num_samples = 0

for _, _, filenames in os.walk('/kaggle/temp/val/'):
    val_num_samples += len(filenames)
    
print("train_num_samples: ",train_num_samples)
print("val_num_samples: ",val_num_samples)
# Out:
# train_num_samples:  5600
# val_num_samples:  1850

# %% [markdown]
# ## Visualize images generated by the Image Generator

# %%
x, y = train_gen.next()
plt.figure(figsize = (15, 15))

for i, (img, label) in enumerate(zip(x, y)):
    plt.subplot(8, 4, i+1)
    
    if label == 0:
        plt.title("with mask")
    else:
        plt.title("without mask")
        
    plt.axis('off')
    plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-5c18f9e11602> in <module>
#       5     plt.subplot(8, 4, i+1)
#       6
# ----> 7     if label == 0:
#       8         plt.title("with mask")
#       9     else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## Create 50 Layer ResNet Model acrhitecture

# %% [markdown]
# Let's first define the identity_block used in ResNet.
#
# ### Identity Block
# The identity block is the standard block used in ResNets, and corresponds to the case where the input activation (say $a^{[l]}$)has the same dimension as the output activation (say $a^{[l+2]}$).
#
# - Use 0 as the seed for random initialization
# - BatchNorm is normalizing the 'channels' axis

# %%
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1,1), strides = (1,1), padding = 'valid', 
               name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1,1), padding='same',
              name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    
    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1,1), strides = (1,1), padding='valid',
              name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name = bn_name_base + '2c')(X)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %% [markdown]
# ### Convolution block
#
# The ResNet "convolution block" is the second block type. You can use this block when the input and the output dimensions don't match up. The difference with the identity block is that there is a Conv2D layer in the shortcut path.
#
# - The Conv2D layer in the shortcut path is used to resize the input X to a different dimension, so that the dimensions match up in the final addition to add the shortcut value back to the main path.
# - For example, to reduce the activation dimensions height and width by a factor of 2, you can use a 1x1 convolution with a stride of 2.

# %%
def convolution_block(X, f, filters, stage, block, s=2):
    """
    Implementation of the convolution block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle Conv's window for the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character , used to name the layers, depending on their position in the network
    s -- integer, specifying the stride to be used
    """
    
    # defining the name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve filters
    F1, F2, F3 = filters
    
    # Save the input
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1,1), strides = (s,s), padding='valid',
              name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1,1), padding='same',
              name=conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    
    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1,1), strides = (1,1), padding='valid',
              name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2c')(X)
    
    # Shortcut path
    X_shortcut = Conv2D(filters = F3, kernel_size = (1,1), strides = (s,s), padding='valid',
                      name=conv_name_base+'1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base+'1')(X_shortcut)
    
    # Final step, Add shortcut value to main path and pass it through a Relu activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %% [markdown]
# ### Building the model
#
# We now have the necessary blocks to build a very deep ResNet. The details of the ResNet-50 model are as follows:
#
# - Stage 1:
#   - The 2D convolution has 64 filters of shape (7,7) and uses a stride of (2,2). Its name is "conv1".
#   - BatchNorm is applied to the channels axis of the input
#   - MaxPooling uses a 3x3 window and a (2,2) stride
# - Stage 2:
#   - The convolution block uses three set of filters of size [64,64,256], "f" is 3, "s" is 1 and the block is "a"
#   - The 2 identity blocks use three sets of filters of size [64,64,256], "f" is 3, and the blocks are "b" and "c"
# - Stage 3:
#   - The convolution block uses three set of filters of size [128,128,512], "f" is 3, "s" is 2 and the block is "a"
#   - Three identity blocks use three sets of filters of size [128,128,512], "f" is 3, and the blocks are "b", "c", and "d"
# - Stage 4:
#   - The convolution block uses three sets of filters of size [256,256,1024],"f" is 3, "s" is 2 and the block is "a"
#   - The 5 identity block use three sets of filters of size [256,256,1024], "f" is 3 and the blocks are "b", "c", "d", "e" and "f"
# - Stage 5:
#   - The convolution block uses three sets of filters of size [512,512,2048], "f" is 3, "s" is 2 and the block is "a"
#   - The 2 identity block use three sets of filters of size [512,512,2048], "f" is 3 and the blocks are "b" and "c"
# - The 2D AveragePooling uses a window of shape (2,2) and its name 'avg_pool'.
# - The 'Flatten' layer doesn't have any hyperparameters or name.
# - The Fully Connected (Dense) layers reduces its input to the number of classes using a softmax activation.

# %%
def ResNet50(input_shape=(64, 64, 3), classes=2):
    
    # define the input as a tensor with shape input_shape
    X_input = Input(shape=input_shape)
    
    # Stage 1
    X = Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding='valid',
              name='conv1', kernel_initializer = glorot_uniform(seed=0))(X_input)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D(pool_size=(3,3), strides=(2,2))(X)
    
    # Stage 2
    X = convolution_block(X, f=3, filters=[64,64,256], stage=2, block='a', s=2)
    X = identity_block(X, f=3, filters=[64,64,256], stage=2, block='b')
    X = identity_block(X, f=3, filters=[64,64,256], stage=2, block='c')
    
    # Stage 3
    X = convolution_block(X, f=3, filters=[128,128,512], stage=3, block='a', s=2)
    X = identity_block(X, f=3, filters=[128,128,512],stage=3, block='b')
    X = identity_block(X, f=3, filters=[128,128,512], stage=3, block='c')
    X = identity_block(X, f=3, filters=[128,128,512], stage=3, block='d')
    
    # Stage 4
    X = convolution_block(X, f=3, filters=[256,256,1024], stage=4, block='a', s=2)
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='b')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='c')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='d')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='e')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='f')
    
    # Stage 5
    X = convolution_block(X, f=3, filters=[512,512,2048], stage=5, block='a', s=2)
    X = identity_block(X, f=3, filters=[512,512,2048], stage=5, block='b')
    X = identity_block(X, f=3, filters=[512,512,2048], stage=5, block='c')
    
    # AVGPool
    X = AveragePooling2D(pool_size=(2,2), padding='same')(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(units=classes, activation='softmax', name='fc' + str(classes), kernel_initializer=glorot_uniform(seed=0))(X)
    
    # create model
    model = keras.Model(inputs = X_input, outputs=X, name='ResNet50')
    
    return model

# %%
model = ResNet50(input_shape = (224,224,3), classes=2)

# print model summary
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 222, 222, 64) 1792        input_8[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 222, 222, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation
0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_367[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_368[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_369[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_367[0][0]
# __________________________________________________________________________________________________
# activation_370 (Activation)     (None, 14, 14, 1024) 0           add_120[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_370[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_371 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_371[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_372 (Activation)     (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_372[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_121 (Add)                   (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_370[0][0]
# __________________________________________________________________________________________________
# activation_373 (Activation)     (None, 14, 14, 1024) 0           add_121[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_373[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_374 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_374[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_375 (Activation)     (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_375[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_122 (Add)                   (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_373[0][0]
# __________________________________________________________________________________________________
# activation_376 (Activation)     (None, 14, 14, 1024) 0           add_122[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_376[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_377 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_377[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_378 (Activation)     (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_378[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_123 (Add)                   (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_376[0][0]
# __________________________________________________________________________________________________
# activation_379 (Activation)     (None, 14, 14, 1024) 0           add_123[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_379[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_380 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_380[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_381 (Activation)     (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_381[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_124 (Add)                   (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_379[0][0]
# __________________________________________________________________________________________________
# activation_382 (Activation)     (None, 14, 14, 1024) 0           add_124[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_382[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_383 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_383[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_384 (Activation)     (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_384[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_382[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_125 (Add)                   (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_385 (Activation)     (None, 7, 7, 2048)   0           add_125[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_385[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_386 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_386[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_387 (Activation)     (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_387[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_126 (Add)                   (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_385[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, 7, 7, 2048)   0           add_126[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_388[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_389 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_389[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_390[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_127 (Add)                   (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_388[0][0]
# __________________________________________________________________________________________________
# activation_391 (Activation)     (None, 7, 7, 2048)   0           add_127[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 4, 4, 2048)   0           activation_391[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 32768)        0           average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 2)            65538       flatten_7[0][0]
# ==================================================================================================
# Total params: 23,645,570
# Trainable params: 23,592,450
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile, Train and Evaluate the model

# %%
# learning rate decay
lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate = 0.001,
                                                         decay_steps = 5,
                                                         decay_rate = 0.2)
# compile the model
model.compile(loss='categorical_crossentropy', 
             optimizer = Adam(learning_rate=0.00002),
             metrics=['accuracy'])

# calculate train_steps and val_steps
train_steps = np.ceil(train_num_samples / train_batch_size)
val_steps = np.ceil(val_num_samples / val_batch_size)
#print(val_steps.dtype)
# train the model
history = model.fit_generator(train_gen,
                             steps_per_epoch = train_steps,
                             epochs = 15,
                             validation_data = val_gen,
                             validation_steps = val_steps)
# Out:
# Epoch 1/15
# 175/175 [==============================] - 120s 683ms/step - loss: 0.9854 - accuracy: 0.7979 - val_loss: 0.4620 - val_accuracy: 0.8286
# Epoch 2/15
# 175/175 [==============================] - 116s 663ms/step - loss: 0.4387 - accuracy: 0.8414 - val_loss: 0.3922 - val_accuracy: 0.8659
# Epoch 3/15
# 175/175 [==============================] - 116s 664ms/step - loss: 0.3235 - accuracy: 0.8718 - val_loss: 0.3270 - val_accuracy: 0.8957
# Epoch 4/15
# 175/175 [==============================] - 117s 667ms/step - loss: 0.2657 - accuracy: 0.8966 - val_loss: 0.2723 - val_accuracy: 0.9065
# Epoch 5/15
# 175/175 [==============================] - 116s 662ms/step - loss: 0.2216 - accuracy: 0.9132 - val_loss: 0.2263 - val_accuracy: 0.9103
# Epoch 6/15
# 175/175 [==============================] - 120s 684ms/step - loss: 0.2011 - accuracy: 0.9264 - val_loss: 0.2075 - val_accuracy: 0.9286
# Epoch 7/15
# 175/175 [==============================] - 122s 698ms/step - loss: 0.1755 - accuracy: 0.9286 - val_loss: 0.1957 - val_accuracy: 0.9249
# Epoch 8/15
# 175/175 [==============================] - 118s 674ms/step - loss: 0.1722 - accuracy: 0.9341 - val_loss: 0.2001 - val_accuracy: 0.9259
# Epoch 9/15
# 175/175 [==============================] - 118s 672ms/step - loss: 0.1607 - accuracy: 0.9389 - val_loss: 0.1751 - val_accuracy: 0.9351
# Epoch 10/15
# 175/175 [==============================] - 118s 674ms/step - loss: 0.1321 - accuracy: 0.9498 - val_loss: 0.1649 - val_accuracy: 0.9432
# Epoch 11/15
# 175/175 [==============================] - 117s 669ms/step - loss: 0.1560 - accuracy: 0.9430 - val_loss: 0.3019 - val_accuracy: 0.9324
# Epoch 12/15
# 175/175 [==============================] - 118s 675ms/step - loss: 0.1183 - accuracy: 0.9539 - val_loss: 0.1524 - val_accuracy: 0.9481
# Epoch 13/15
# 175/175 [==============================] - 119s 679ms/step - loss: 0.1280 - accuracy: 0.9539 - val_loss: 0.1415 - val_accuracy: 0.9427
# Epoch 14/15
# 175/175 [==============================] - 120s 687ms/step - loss: 0.1105 - accuracy: 0.9604 - val_loss: 0.1350 - val_accuracy: 0.9573
# Epoch 15/15
# 175/175 [==============================] - 120s 683ms/step - loss: 0.1046 - accuracy: 0.9607 - val_loss: 0.1295 - val_accuracy: 0.9595

# %%
# plot the accuracy of the model
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# plot the loss of the model
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train','val'], loc='upper left')
plt.show()

# save the model
model.save("/kaggle/working/face_mask_detection.h5")
